# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
qc_dir = os.path.normpath('Y:/home/rna_seq_data/20210315_pombe_ox_bulk/FastQC/multiqc_data')

qc_fname = qc_dir + os.sep + 'multiqc_fastqc.txt'

qc_table = pd.read_table(qc_fname, index_col=0)

# %%
qc_table
# Out:
#                                                        Filename  \
# Sample
# BMH_758_20_L_S28_R1_001        BMH_758_20_L_S28_R1_001.fastq.gz
# BMH_758_20_L_S28_R2_001        BMH_758_20_L_S28_R2_001.fastq.gz
# BMH_758_20_M_S5_R1_001          BMH_758_20_M_S5_R1_001.fastq.gz
# BMH_758_20_M_S5_R2_001          BMH_758_20_M_S5_R2_001.fastq.gz
# BMH_758_20_cont_S3_R1_001    BMH_758_20_cont_S3_R1_001.fastq.gz
# BMH_758_20_cont_S3_R2_001    BMH_758_20_cont_S3_R2_001.fastq.gz
# BMH_758_60_L_S19_R1_001        BMH_758_60_L_S19_R1_001.fastq.gz
# BMH_758_60_L_S19_R2_001        BMH_758_60_L_S19_R2_001.fastq.gz
# BMH_758_60_M_S20_R1_001        BMH_758_60_M_S20_R1_001.fastq.gz
# BMH_758_60_M_S20_R2_001        BMH_758_60_M_S20_R2_001.fastq.gz
# BMH_758_60_cont_S6_R1_001    BMH_758_60_cont_S6_R1_001.fastq.gz
# BMH_758_60_cont_S6_R2_001    BMH_758_60_cont_S6_R2_001.fastq.gz
# BMH_759_20_L_S21_R1_001        BMH_759_20_L_S21_R1_001.fastq.gz
# ...

# %%
plt.hist(qc_table['total_deduplicated_percentage'])
# Out:
# (array([ 2.,  2.,  7., 13., 10., 14.,  5.,  3.,  3.,  1.]),
#  array([24.84124907, 25.7404654 , 26.63968174, 27.53889808, 28.43811441,
#         29.33733075, 30.23654708, 31.13576342, 32.03497975, 32.93419609,
#         33.83341243]),
#  <a list of 10 Patch objects>)
